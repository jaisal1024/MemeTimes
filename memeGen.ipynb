# %%
import pyimgflip
api = pyimgflip.Imgflip()
memes = api.get_memes()
#fields in meme: id, name, url, width, height
for meme in memes:
    print(meme.url)
# Out:
# https://i.imgflip.com/1ur9b0.jpg
# https://i.imgflip.com/2kbn1e.jpg
# https://i.imgflip.com/1g8my4.jpg
# https://i.imgflip.com/1jwhww.jpg
# https://i.imgflip.com/1otk96.jpg
# https://i.imgflip.com/9ehk.jpg
# https://i.imgflip.com/22bdq6.jpg
# https://i.imgflip.com/1h7in3.jpg
# https://i.imgflip.com/2fm6x.jpg
# https://i.imgflip.com/1yxkcp.jpg
# https://i.imgflip.com/1o00in.jpg
# https://i.imgflip.com/1bij.jpg
# https://i.imgflip.com/m78d.jpg
# https://i.imgflip.com/1w7ygt.jpg
# https://i.imgflip.com/26am.jpg
# https://i.imgflip.com/gk5el.jpg
# https://i.imgflip.com/2896ro.jpg
# https://i.imgflip.com/1bgw.jpg
# https://i.imgflip.com/21tqf4.jpg
# https://i.imgflip.com/gtj5t.jpg
# https://i.imgflip.com/1bh8.jpg
# https://i.imgflip.com/21uy0f.jpg
# https://i.imgflip.com/1ii4oc.jpg
# https://i.imgflip.com/grr.jpg
# https://i.imgflip.com/1ihzfe.jpg
# https://i.imgflip.com/271ps6.jpg
# https://i.imgflip.com/23ls.jpg
# https://i.imgflip.com/1bhm.jpg
# https://i.imgflip.com/1e7ql7.jpg
# https://i.imgflip.com/3pnmg.jpg
# https://i.imgflip.com/1bip.jpg
# https://i.imgflip.com/39t1o.jpg
# https://i.imgflip.com/c2qn.jpg
# https://i.imgflip.com/265k.jpg
# https://i.imgflip.com/1bh3.jpg
# https://i.imgflip.com/1ooaki.jpg
# https://i.imgflip.com/8h0c8.jpg
# https://i.imgflip.com/9sw43.jpg
# https://i.imgflip.com/1bhf.jpg
# https://i.imgflip.com/1bim.jpg
# https://i.imgflip.com/1bh9.jpg
# https://i.imgflip.com/1bhw.jpg
# https://i.imgflip.com/4t0m5.jpg
# https://i.imgflip.com/1bhk.jpg
# https://i.imgflip.com/wczz.jpg
# https://i.imgflip.com/26br.jpg
# https://i.imgflip.com/5kdc.jpg
# https://i.imgflip.com/jrj7.jpg
# https://i.imgflip.com/1bil.jpg
# https://i.imgflip.com/25w3.jpg
# https://i.imgflip.com/8k0sa.jpg
# https://i.imgflip.com/51s5.jpg
# https://i.imgflip.com/5mcpl.jpg
# https://i.imgflip.com/odluv.jpg
# https://i.imgflip.com/xh3me.jpg
# https://i.imgflip.com/265j.jpg
# https://i.imgflip.com/2cp1.jpg
# https://i.imgflip.com/8p0a.jpg
# https://i.imgflip.com/1bgs.jpg
# https://i.imgflip.com/9iz9.jpg
# https://i.imgflip.com/1wz1x.jpg
# https://i.imgflip.com/28s2gu.jpg
# https://i.imgflip.com/59qi.jpg
# https://i.imgflip.com/1bik.jpg
# https://i.imgflip.com/1b94pe.jpg
# https://i.imgflip.com/1x6f.jpg
# https://i.imgflip.com/7yk6.jpg
# https://i.imgflip.com/9vct.jpg
# https://i.imgflip.com/3vzej.jpg
# https://i.imgflip.com/1nck6k.jpg
# https://i.imgflip.com/26hg.jpg
# https://i.imgflip.com/3i7p.jpg
# https://i.imgflip.com/46rh.jpg
# https://i.imgflip.com/cv1y0.jpg
# https://i.imgflip.com/s4f1k.jpg
# https://i.imgflip.com/4bh6h.jpg
# https://i.imgflip.com/hmt3v.jpg
# https://i.imgflip.com/2d3al6.jpg
# https://i.imgflip.com/1866qe.jpg
# https://i.imgflip.com/2nuc.jpg
# https://i.imgflip.com/govs4.jpg
# https://i.imgflip.com/12dxv.jpg
# https://i.imgflip.com/2d9dey.jpg
# https://i.imgflip.com/269s.jpg
# https://i.imgflip.com/qep4.jpg
# https://i.imgflip.com/8u2b.jpg
# https://i.imgflip.com/25wb.jpg
# https://i.imgflip.com/2dt3rd.jpg
# https://i.imgflip.com/3d24.jpg
# https://i.imgflip.com/gft6.jpg
# https://i.imgflip.com/bfq76.jpg
# https://i.imgflip.com/15hg.jpg
# https://i.imgflip.com/1bio.jpg
# https://i.imgflip.com/3si4.jpg
# https://i.imgflip.com/10r5wh.jpg
# https://i.imgflip.com/7dusq.jpg
# https://i.imgflip.com/2b5p.jpg
# https://i.imgflip.com/4vy0.jpg
# https://i.imgflip.com/dnn.jpg
# https://i.imgflip.com/2jy24u.jpg

# %%
# !pip install python-ninegag
# Out:
# Collecting python-ninegag
#   Downloading https://files.pythonhosted.org/packages/90/b8/dfe3d4119c7c007754f6a3189349cfdadcf54d680483383fa3a6f012485e/python-ninegag-1.0.zip
# Requirement already satisfied: beautifulsoup4 in c:\users\artem\anaconda3\lib\site-packages (from python-ninegag) (4.6.0)
# Requirement already satisfied: requests in c:\users\artem\anaconda3\lib\site-packages (from python-ninegag) (2.18.4)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\artem\anaconda3\lib\site-packages (from requests->python-ninegag) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\users\artem\anaconda3\lib\site-packages (from requests->python-ninegag) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\artem\anaconda3\lib\site-packages (from requests->python-ninegag) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\artem\anaconda3\lib\site-packages (from requests->python-ninegag) (2018.4.16)
# Building wheels for collected packages: python-ninegag
#   Running setup.py bdist_wheel for python-ninegag: started
#   Running setup.py bdist_wheel for python-ninegag: finished with status 'done'
#   Stored in directory: C:\Users\Artem\AppData\Local\pip\Cache\wheels\1d\de\57\3523a269d3474ab9f816fe2a5d5380d8c2026e27d7a08b476b
# Successfully built python-ninegag
# Installing collected packages: python-ninegag
# Successfully installed python-ninegag-1.0

# %%
import pyninegag
pyninegag.get_sections()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-b0734a69911f> in <module>()
#       1 import pyninegag
# ----> 2 pyninegag.get_sections()
#
# ~\Anaconda3\lib\site-packages\pyninegag.py in get_sections()
#      64     if _sections is None:
#      65         bs = _bs_from_url(BASE_URL)
# ---> 66         l = bs.find(attrs='nav-menu').find(attrs='primary').find_all('li')[1:-1]
#      67         l.extend(bs.find_all(attrs="badge-section-menu-items"))
#      68         _sections = dict((i.a.text.strip(), i.a['href']) for i in l)
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
import requests
import json

def getSentiment(text):
    endpoint = "https://gateway.watsonplatform.net/natural-language-understanding/api/v1/analyze"

    # You can register and get your own credentials
    # The ones below have a quota of 1000 calls per day 
    # and can run out quickly if multiple people use these
    username = "711b4792-170d-490f-ac0e-5d785a271868"
    password = "No7JUOE1UOYu"
    
    parameters = {
        'features': 'emotion,sentiment',
        'version' : '2017-02-27',
        'text': text,
        'language' : 'en',
        # url = url_to_analyze, this is an alternative to sending the text
    }

    resp = requests.get(endpoint, params=parameters, auth=(username, password))
    
    return resp.json()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np
import requests
import json

# See documentation at https://cloud.google.com/vision/docs/reference/rest/v1/images/annotate#Type

# We will run the following detections for the image in the passed URL
# FACE_DETECTION	Run face detection.
# WEB_DETECTION	Run web detection.
# LABEL_DETECTION	Run label detection.
#
def process_image_google(url):
    endpoint_google_vision = "https://vision.googleapis.com/v1/images:annotate"
    params = {
        'key': 'AIzaSyCD4d_pZuL-RQfwmqRwy0I2KJEaOOHsUVg',
    }
    headers = { 
        'Content-Type': 'application/json',
    }
    gvision_data = {
      "requests": [
        {
          "image":{
            "source": {
                "imageUri" : url
            }
          },
          "features": [ { "type": "FACE_DETECTION" },  
                        { "type": "LABEL_DETECTION" },
                        { "type": "WEB_DETECTION" } ]
        }
      ]
    }

    resp = requests.post(
        endpoint_google_vision, 
        data=json.dumps(gvision_data), 
        headers=headers,
        params=params 
    )
    
    data = resp.json()
#     return data
    return data['responses'][0]

# %%
for meme in memes:
    text = meme.name
    print(text)
    data = getSentiment(text)
    gVision = process_image_google(meme.url)
    print(gVision.keys())
    
#     print(data['language'])
#     print(data['sentiment'])
    print(data['emotion'])
# Out:
# Distracted Boyfriend
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.406042, 'joy': 0.21586, 'fear': 0.201631, 'disgust': 0.092165, 'anger': 0.098007}}}
# Surprised Pikachu
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.166389, 'joy': 0.53245, 'fear': 0.003328, 'disgust': 0.285277, 'anger': 0.01068}}}
# Two Buttons
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.326189, 'joy': 0.220076, 'fear': 0.116564, 'disgust': 0.062465, 'anger': 0.112295}}}
# Expanding Brain
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.11621, 'joy': 0.152882, 'fear': 0.156088, 'disgust': 0.114064, 'anger': 0.573438}}}
# Mocking Spongebob
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.167521, 'joy': 0.10945, 'fear': 0.216691, 'disgust': 0.281442, 'anger': 0.070342}}}
# Batman Slapping Robin
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.155726, 'joy': 0.110739, 'fear': 0.066316, 'disgust': 0.233548, 'anger': 0.372346}}}
# Left Exit 12 Off Ramp
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.264925, 'joy': 0.181965, 'fear': 0.100673, 'disgust': 0.083638, 'anger': 0.128604}}}
# Roll Safe Think About It
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.11043, 'joy': 0.142569, 'fear': 0.098562, 'disgust': 0.053886, 'anger': 0.061638}}}
# Waiting Skeleton
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.234225, 'joy': 0.153066, 'fear': 0.128212, 'disgust': 0.060814, 'anger': 0.237285}}}
# Blank Nut Button
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.434092, 'joy': 0.029342, 'fear': 0.116805, 'disgust': 0.180144, 'anger': 0.169826}}}
# Is This A Pigeon
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.0, 'joy': 0.0, 'fear': 0.0, 'disgust': 0.0, 'anger': 0.0}}}
# One Does Not Simply
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.163951, 'joy': 0.194561, 'fear': 0.08248, 'disgust': 0.07836, 'anger': 0.092968}}}
# Boardroom Meeting Suggestion
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.04972, 'joy': 0.295179, 'fear': 0.088674, 'disgust': 0.000787, 'anger': 0.055393}}}
# Inhaling Seagull
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.144548, 'joy': 0.182754, 'fear': 0.087573, 'disgust': 0.089045, 'anger': 0.099738}}}
# Ancient Aliens
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.16116, 'joy': 0.185229, 'fear': 0.085766, 'disgust': 0.078321, 'anger': 0.083191}}}
# Hide the Pain Harold
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.796857, 'joy': 0.025142, 'fear': 0.233858, 'disgust': 0.033057, 'anger': 0.124018}}}
# American Chopper Argument
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.433302, 'joy': 0.079116, 'fear': 0.036954, 'disgust': 0.226854, 'anger': 0.436598}}}
# Futurama Fry
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.144548, 'joy': 0.186295, 'fear': 0.087573, 'disgust': 0.077654, 'anger': 0.082912}}}
# The Scroll Of Truth
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.326789, 'joy': 0.381784, 'fear': 0.098956, 'disgust': 0.06512, 'anger': 0.077267}}}
# Oprah You Get A
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.173086, 'joy': 0.59262, 'fear': 0.163383, 'disgust': 0.031234, 'anger': 0.054696}}}
# The Most Interesting Man In The World
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.10326, 'joy': 0.82295, 'fear': 0.01229, 'disgust': 0.011435, 'anger': 0.061891}}}
# Y'all Got Any More Of That
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.0, 'joy': 0.0, 'fear': 0.0, 'disgust': 0.0, 'anger': 0.0}}}
# Trump Bill Signing
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.239259, 'joy': 0.037927, 'fear': 0.052432, 'disgust': 0.286241, 'anger': 0.139693}}}
# The Rock Driving
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.020031, 'joy': 0.662652, 'fear': 0.119437, 'disgust': 0.029011, 'anger': 0.139788}}}
# X, X Everywhere
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.212473, 'joy': 0.095775, 'fear': 0.216066, 'disgust': 0.215507, 'anger': 0.073543}}}
# Hard To Swallow Pills
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.629001, 'joy': 0.026238, 'fear': 0.39981, 'disgust': 0.133427, 'anger': 0.072342}}}
# Disaster Girl
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.313135, 'joy': 0.051308, 'fear': 0.077786, 'disgust': 0.624425, 'anger': 0.190042}}}
# Brace Yourselves X is Coming
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.180738, 'joy': 0.249275, 'fear': 0.116563, 'disgust': 0.06977, 'anger': 0.100277}}}
# Evil Kermit
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.064482, 'joy': 0.017969, 'fear': 0.316651, 'disgust': 0.316296, 'anger': 0.636974}}}
# Finding Neverland
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.102098, 'joy': 0.363427, 'fear': 0.155623, 'disgust': 0.070634, 'anger': 0.044187}}}
# Bad Luck Brian
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.562483, 'joy': 0.033793, 'fear': 0.208219, 'disgust': 0.168692, 'anger': 0.291312}}}
# Leonardo Dicaprio Cheers
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.208506, 'joy': 0.542737, 'fear': 0.027, 'disgust': 0.064465, 'anger': 0.040604}}}
# That Would Be Great
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.057417, 'joy': 0.789553, 'fear': 0.034487, 'disgust': 0.036191, 'anger': 0.011095}}}
# Third World Skeptical Kid
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.33173, 'joy': 0.398085, 'fear': 0.090821, 'disgust': 0.131466, 'anger': 0.122318}}}
# Y U No
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.175541, 'joy': 0.141365, 'fear': 0.109287, 'disgust': 0.071021, 'anger': 0.094718}}}
# Who Would Win?
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.053509, 'joy': 0.726701, 'fear': 0.043868, 'disgust': 0.074603, 'anger': 0.089204}}}
# Black Girl Wat
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.123633, 'joy': 0.367912, 'fear': 0.132314, 'disgust': 0.438243, 'anger': 0.074035}}}
# But Thats None Of My Business
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.048057, 'joy': 0.503155, 'fear': 0.026664, 'disgust': 0.060252, 'anger': 0.073747}}}
# First World Problems
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.451028, 'joy': 0.330731, 'fear': 0.117027, 'disgust': 0.061952, 'anger': 0.103058}}}
# Creepy Condescending Wonka
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.101044, 'joy': 0.025919, 'fear': 0.830746, 'disgust': 0.083749, 'anger': 0.090045}}}
# X All The Y
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.0, 'joy': 0.0, 'fear': 0.0, 'disgust': 0.0, 'anger': 0.0}}}
# Grandma Finds The Internet
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.186637, 'joy': 0.302018, 'fear': 0.153545, 'disgust': 0.045094, 'anger': 0.114689}}}
# Doge
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.0, 'joy': 0.0, 'fear': 0.0, 'disgust': 0.0, 'anger': 0.0}}}
# Success Kid
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.007244, 'joy': 0.924324, 'fear': 0.02213, 'disgust': 0.021268, 'anger': 0.003691}}}
# Captain Picard Facepalm
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.146667, 'joy': 0.169369, 'fear': 0.096865, 'disgust': 0.054809, 'anger': 0.110967}}}
# Dont You Squidward
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.141719, 'joy': 0.191139, 'fear': 0.08519, 'disgust': 0.078108, 'anger': 0.091797}}}
# Am I The Only One Around Here
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.177729, 'joy': 0.295295, 'fear': 0.162256, 'disgust': 0.048126, 'anger': 0.22917}}}
# Laughing Men In Suits
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.073677, 'joy': 0.696905, 'fear': 0.047646, 'disgust': 0.147304, 'anger': 0.091117}}}
# Put It Somewhere Else Patrick
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.308045, 'joy': 0.138158, 'fear': 0.112333, 'disgust': 0.10116, 'anger': 0.268645}}}
# Matrix Morpheus
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.144548, 'joy': 0.18067, 'fear': 0.118627, 'disgust': 0.077654, 'anger': 0.090723}}}
# Star Wars Yoda
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.267253, 'joy': 0.487916, 'fear': 0.108088, 'disgust': 0.045879, 'anger': 0.116856}}}
# Evil Toddler
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.113752, 'joy': 0.045224, 'fear': 0.177626, 'disgust': 0.282654, 'anger': 0.57009}}}
# Face You Make Robert Downey Jr
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.03642, 'joy': 0.104176, 'fear': 0.139444, 'disgust': 0.095858, 'anger': 0.035535}}}
# Dr Evil Laser
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.110414, 'joy': 0.086218, 'fear': 0.278986, 'disgust': 0.190882, 'anger': 0.452333}}}
# Be Like Bill
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.079825, 'joy': 0.133134, 'fear': 0.042608, 'disgust': 0.220488, 'anger': 0.214293}}}
# Third World Success Kid
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.064124, 'joy': 0.847105, 'fear': 0.037857, 'disgust': 0.03125, 'anger': 0.018612}}}
# Ill Just Wait Here
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.493427, 'joy': 0.018372, 'fear': 0.361849, 'disgust': 0.058815, 'anger': 0.371906}}}
# Grumpy Cat
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.063213, 'joy': 0.089075, 'fear': 0.036441, 'disgust': 0.01318, 'anger': 0.78983}}}
# Philosoraptor
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.0, 'joy': 0.0, 'fear': 0.0, 'disgust': 0.0, 'anger': 0.0}}}
# Maury Lie Detector
# dict_keys(['faceAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.308503, 'joy': 0.009265, 'fear': 0.078733, 'disgust': 0.301014, 'anger': 0.58908}}}
# This Is Where I'd Put My Trophy If I Had One
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.183352, 'joy': 0.218019, 'fear': 0.093246, 'disgust': 0.170382, 'anger': 0.311899}}}
# Who Killed Hannibal
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.395245, 'joy': 0.002555, 'fear': 0.249455, 'disgust': 0.126563, 'anger': 0.589031}}}
# Picard Wtf
# dict_keys(['faceAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.066405, 'joy': 0.002526, 'fear': 0.061222, 'disgust': 0.258067, 'anger': 0.87782}}}
# Too Damn High
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.167621, 'joy': 0.034452, 'fear': 0.207461, 'disgust': 0.108258, 'anger': 0.739032}}}
# Blank Starter Pack
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.468752, 'joy': 0.032882, 'fear': 0.278638, 'disgust': 0.035024, 'anger': 0.084225}}}
# Uncle Sam
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.336722, 'joy': 0.052428, 'fear': 0.326278, 'disgust': 0.27715, 'anger': 0.034516}}}
# Simba Shadowy Place
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.080711, 'joy': 0.480431, 'fear': 0.039169, 'disgust': 0.055071, 'anger': 0.099509}}}
# Jack Sparrow Being Chased
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.285015, 'joy': 0.124177, 'fear': 0.117444, 'disgust': 0.129453, 'anger': 0.125684}}}
# See Nobody Cares
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.141719, 'joy': 0.186286, 'fear': 0.123368, 'disgust': 0.078108, 'anger': 0.091797}}}
# Sleeping Shaq
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.26056, 'joy': 0.244534, 'fear': 0.483383, 'disgust': 0.071942, 'anger': 0.09129}}}
# Yo Dawg Heard You
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.155559, 'joy': 0.192687, 'fear': 0.172533, 'disgust': 0.085301, 'anger': 0.285994}}}
# Imagination Spongebob
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.123795, 'joy': 0.185384, 'fear': 0.24164, 'disgust': 0.072303, 'anger': 0.083125}}}
# Sparta Leonidas
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.144548, 'joy': 0.185315, 'fear': 0.087573, 'disgust': 0.077654, 'anger': 0.090723}}}
# Mugatu So Hot Right Now
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.070916, 'joy': 0.580425, 'fear': 0.117971, 'disgust': 0.131759, 'anger': 0.091455}}}
# Good Fellas Hilarious
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.046115, 'joy': 0.82189, 'fear': 0.021829, 'disgust': 0.008257, 'anger': 0.047013}}}
# Kevin Hart
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.216307, 'joy': 0.094181, 'fear': 0.064779, 'disgust': 0.052249, 'anger': 0.062114}}}
# Look At Me
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.0, 'joy': 0.0, 'fear': 0.0, 'disgust': 0.0, 'anger': 0.0}}}
# Car Salesman Slaps Roof Of Car
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.095754, 'joy': 0.060568, 'fear': 0.22026, 'disgust': 0.217067, 'anger': 0.483}}}
# Arthur Fist
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.029669, 'joy': 0.111667, 'fear': 0.125399, 'disgust': 0.120892, 'anger': 0.2153}}}
# Say That Again I Dare You
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.092195, 'joy': 0.067365, 'fear': 0.059656, 'disgust': 0.457763, 'anger': 0.566855}}}
# Marvel Civil War 1
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.310215, 'joy': 0.13424, 'fear': 0.19917, 'disgust': 0.146481, 'anger': 0.175098}}}
# And everybody loses their minds
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.490186, 'joy': 0.093178, 'fear': 0.170301, 'disgust': 0.058455, 'anger': 0.411751}}}
# Car Salesman Slaps Hood
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.119229, 'joy': 0.055386, 'fear': 0.110169, 'disgust': 0.261023, 'anger': 0.52754}}}
# 10 Guy
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.0, 'joy': 0.0, 'fear': 0.0, 'disgust': 0.0, 'anger': 0.0}}}
# Pepperidge Farm Remembers
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.450431, 'joy': 0.229652, 'fear': 0.131877, 'disgust': 0.038351, 'anger': 0.061909}}}
# Jackie Chan WTF
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.109145, 'joy': 0.014194, 'fear': 0.067058, 'disgust': 0.197757, 'anger': 0.823094}}}
# Confession Bear
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.192511, 'joy': 0.292184, 'fear': 0.077911, 'disgust': 0.108511, 'anger': 0.216398}}}
# Young Cardi B
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.402924, 'joy': 0.340407, 'fear': 0.152598, 'disgust': 0.023355, 'anger': 0.114023}}}
# Inception
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.0, 'joy': 0.0, 'fear': 0.0, 'disgust': 0.0, 'anger': 0.0}}}
# Aaaaand Its Gone
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.414128, 'joy': 0.124196, 'fear': 0.418191, 'disgust': 0.042746, 'anger': 0.169367}}}
# What Do We Want
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.916667, 'joy': 0.0, 'fear': 0.0, 'disgust': 0.0, 'anger': 0.0}}}
# Peter Parker Cry
# dict_keys(['faceAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.902651, 'joy': 0.016688, 'fear': 0.068094, 'disgust': 0.071867, 'anger': 0.038335}}}
# Socially Awesome Awkward Penguin
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.148332, 'joy': 0.733743, 'fear': 0.042584, 'disgust': 0.034905, 'anger': 0.023169}}}
# Shut Up And Take My Money Fry
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.140329, 'joy': 0.031457, 'fear': 0.072334, 'disgust': 0.182969, 'anger': 0.757825}}}
# Mr Krabs Blur Meme
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.123013, 'joy': 0.172585, 'fear': 0.082965, 'disgust': 0.061751, 'anger': 0.170959}}}
# Bad Pun Dog
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.43202, 'joy': 0.017572, 'fear': 0.270535, 'disgust': 0.378888, 'anger': 0.22589}}}
# Spiderman Peter Parker
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.173832, 'joy': 0.173977, 'fear': 0.069207, 'disgust': 0.145737, 'anger': 0.095473}}}
# Liam Neeson Taken
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.206246, 'joy': 0.068403, 'fear': 0.07191, 'disgust': 0.262942, 'anger': 0.164338}}}
# Buddy Christ
# dict_keys(['faceAnnotations', 'labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.086558, 'joy': 0.675741, 'fear': 0.058224, 'disgust': 0.006077, 'anger': 0.121436}}}
# NPC
# dict_keys(['labelAnnotations', 'webDetection'])
# {'document': {'emotion': {'sadness': 0.0, 'joy': 0.0, 'fear': 0.0, 'disgust': 0.0, 'anger': 0.0}}}

# %%
import pyimgflip
import random
api = pyimgflip.Imgflip(username='meisrt', password='5r8I4544')
memes = api.get_memes()
meme = random.choice(memes)
print("Generating a meme from template: " + meme.name)
result = api.caption_image(meme, "Top Text", "Bottom Text")
print("Meme available at URL: " + result['url'])
# Out:
# Generating a meme from template: Uncle Sam
# Meme available at URL: http://i.imgflip.com/2o2uhx.jpg
